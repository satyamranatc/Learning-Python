# %%
import numpy as np
import pandas as pd

# %%
arr = np.random.randint(10,size=(5,5))
arr
# Out:
# array([[1, 9, 2, 2, 7],
#        [8, 0, 5, 4, 5],
#        [2, 8, 1, 2, 2],
#        [2, 8, 2, 4, 9],
#        [7, 3, 9, 0, 1]])

# %%
df = pd.DataFrame(arr)
df
# Out:
#    0  1  2  3  4
# 0  1  9  2  2  7
# 1  8  0  5  4  5
# 2  2  8  1  2  2
# 3  2  8  2  4  9
# 4  7  3  9  0  1

# %%
df[0]
# Out:
# 0    1
# 1    8
# 2    2
# 3    2
# 4    7
# Name: 0, dtype: int64

# %%
df[df[0]>3]
# Out:
#    0  1  2  3  4
# 1  8  0  5  4  5
# 4  7  3  9  0  1

# %%
df.describe()
# Out:
#              0         1         2        3        4
# count  5.00000  5.000000  5.000000  5.00000  5.00000
# mean   4.00000  5.600000  3.800000  2.40000  4.80000
# std    3.24037  3.911521  3.271085  1.67332  3.34664
# min    1.00000  0.000000  1.000000  0.00000  1.00000
# 25%    2.00000  3.000000  2.000000  2.00000  2.00000
# 50%    2.00000  8.000000  2.000000  2.00000  5.00000
# 75%    7.00000  8.000000  5.000000  4.00000  7.00000
# max    8.00000  9.000000  9.000000  4.00000  9.00000

# %%
df[1].describe()
# Out:
# count    5.000000
# mean     5.600000
# std      3.911521
# min      0.000000
# 25%      3.000000
# 50%      8.000000
# 75%      8.000000
# max      9.000000
# Name: 1, dtype: float64

# %%
df[2].max()
# Out:
# 9

# %%
df.isna()
# Out:
#        0      1      2      3      4
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False  False  False  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False

# %%
MyData = pd.read_csv("./indian_food.csv")
MyData
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
MyData.head()
MyData.tail()
# Out:
#           name                                        ingredients        diet  \
# 250  Til Pitha            Glutinous rice, black sesame seeds, gur  vegetarian
# 251    Bebinca  Coconut milk, egg yolks, clarified butter, all...  vegetarian
# 252     Shufta  Cottage cheese, dry dates, dried rose petals, ...  vegetarian
# 253  Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...  vegetarian
# 254     Pinaca  Brown rice, fennel seeds, grated coconut, blac...  vegetarian
#
#      prep_time  cook_time flavor_profile   course            state      region
# 250          5         30          sweet  dessert            Assam  North East
# 251         20         60          sweet  dessert              Goa        West
# 252         -1         -1          sweet  dessert  Jammu & Kashmir       North
# 253         20         45          sweet  dessert   Madhya Pradesh     Central
# 254         -1         -1          sweet  dessert              Goa        West

# %%
MyData.describe()
# Out:
#         prep_time   cook_time
# count  255.000000  255.000000
# mean    31.105882   34.529412
# std     72.554409   48.265650
# min     -1.000000   -1.000000
# 25%     10.000000   20.000000
# 50%     10.000000   30.000000
# 75%     20.000000   40.000000
# max    500.000000  720.000000

# %%
MyData.shape
# Out:
# (255, 9)

# %%
MyData.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %%
MyData.isna().sum()
# Out:
# name              0
# ingredients       0
# diet              0
# prep_time         0
# cook_time         0
# flavor_profile    0
# course            0
# state             0
# region            1
# dtype: int64

# %%
MyData["region"][MyData["region"].isna()]
# Out:
# 110    NaN
# Name: region, dtype: object

# %%
MyData["region"][105:111]
# Out:
# 105    North
# 106    North
# 107    North
# 108    North
# 109       -1
# 110      NaN
# Name: region, dtype: object

# %%
df = pd.read_csv("./Test2.csv")

# %%
df.head(12)
# Out:
#               name                                        ingredients  \
# 0       Balu shahi                    Maida flour, yogurt, oil, sugar
# 1           Boondi                            Gram flour, ghee, sugar
# 2   Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3           Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4      Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5           Imarti                          Sugar syrup, lentil flour
# 6           Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7       Kaju katli                     Cashews, ghee, cardamom, sugar
# 8         Kalakand                        Milk, cottage cheese, sugar
# 9            Kheer                    Milk, rice, sugar, dried fruits
# 10           Laddu                            Gram flour, ghee, sugar
# 11           Lassi                          Yogurt, milk, nuts, sugar
#
# ...

# %%
df.isna().sum()
# Out:
# name              0
# ingredients       0
# diet              1
# prep_time         1
# cook_time         2
# flavor_profile    3
# course            0
# state             0
# region            0
# dtype: int64

# %%
df["cook_time"]
# Out:
# 0     25.0
# 1     30.0
# 2     60.0
# 3     30.0
# 4      NaN
# 5     50.0
# 6     50.0
# 7      NaN
# 8     30.0
# 9     40.0
# 10    40.0
# 11     5.0
# 12    30.0
# Name: cook_time, dtype: float64

# %%
df["cook_time"].dropna(inplace= True)

# %%
print(df['cook_time'].dtype)
# Out:
# float64

# %%
print(df['cook_time'].isna().any())
# Out:
# True

# %%
df.dropna(subset=['cook_time'], inplace=True)

# %%
df
# Out:
#               name                                        ingredients  \
# 0       Balu shahi                    Maida flour, yogurt, oil, sugar
# 1           Boondi                            Gram flour, ghee, sugar
# 2   Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3           Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4      Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5           Imarti                          Sugar syrup, lentil flour
# 6           Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7       Kaju katli                     Cashews, ghee, cardamom, sugar
# 8         Kalakand                        Milk, cottage cheese, sugar
# 9            Kheer                    Milk, rice, sugar, dried fruits
# 10           Laddu                            Gram flour, ghee, sugar
# 11           Lassi                          Yogurt, milk, nuts, sugar
# ...

# %%
df["cook_time"].isna().any()
# Out:
# True

# %%
df["cook_time"].mean()
# Out:
# 35.45454545454545

# %%
df["cook_time"].fillna(df["cook_time"].mean(), inplace=True)

# %%
pd.to_datetime(df["cook_time"])
# Out:
# 0    1970-01-01 00:00:00.000000025
# 1    1970-01-01 00:00:00.000000030
# 2    1970-01-01 00:00:00.000000060
# 3    1970-01-01 00:00:00.000000030
# 4    1970-01-01 00:00:00.000000035
# 5    1970-01-01 00:00:00.000000050
# 6    1970-01-01 00:00:00.000000050
# 7    1970-01-01 00:00:00.000000035
# 8    1970-01-01 00:00:00.000000030
# 9    1970-01-01 00:00:00.000000040
# 10   1970-01-01 00:00:00.000000040
# 11   1970-01-01 00:00:00.000000005
# 12   1970-01-01 00:00:00.000000030
# Name: cook_time, dtype: datetime64[ns]

# %%
df["cook_time"]
# Out:
# 0     25.000000
# 1     30.000000
# 2     60.000000
# 3     30.000000
# 4     35.454545
# 5     50.000000
# 6     50.000000
# 7     35.454545
# 8     30.000000
# 9     40.000000
# 10    40.000000
# 11     5.000000
# 12    30.000000
# Name: cook_time, dtype: float64

# %%
df.loc[2, 'cook_time'] = 45

# %%
df
# Out:
#               name                                        ingredients  \
# 0       Balu shahi                    Maida flour, yogurt, oil, sugar
# 1           Boondi                            Gram flour, ghee, sugar
# 2   Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3           Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4      Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5           Imarti                          Sugar syrup, lentil flour
# 6           Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7       Kaju katli                     Cashews, ghee, cardamom, sugar
# 8         Kalakand                        Milk, cottage cheese, sugar
# 9            Kheer                    Milk, rice, sugar, dried fruits
# 10           Laddu                            Gram flour, ghee, sugar
# 11           Lassi                          Yogurt, milk, nuts, sugar
# ...

# %%
for x in df.index:
    if df.loc[x, 'cook_time'] > 35:
        df.loc[x, 'cook_time'] = 30

# %%
df.duplicated().any()
# Out:
# False

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#               name                                        ingredients  \
# 0       Balu shahi                    Maida flour, yogurt, oil, sugar
# 1           Boondi                            Gram flour, ghee, sugar
# 2   Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3           Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4      Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5           Imarti                          Sugar syrup, lentil flour
# 6           Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7       Kaju katli                     Cashews, ghee, cardamom, sugar
# 8         Kalakand                        Milk, cottage cheese, sugar
# 9            Kheer                    Milk, rice, sugar, dried fruits
# 10           Laddu                            Gram flour, ghee, sugar
# 11           Lassi                          Yogurt, milk, nuts, sugar
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            13 non-null     object
#  1   ingredients     13 non-null     object
#  2   diet            12 non-null     object
#  3   prep_time       12 non-null     float64
#  4   cook_time       13 non-null     float64
#  5   flavor_profile  10 non-null     object
#  6   course          13 non-null     object
#  7   state           13 non-null     object
#  8   region          13 non-null     object
# dtypes: float64(2), object(7)
# memory usage: 1.0+ KB

# %%
df
# Out:
#               name                                        ingredients  \
# 0       Balu shahi                    Maida flour, yogurt, oil, sugar
# 1           Boondi                            Gram flour, ghee, sugar
# 2   Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3           Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4      Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5           Imarti                          Sugar syrup, lentil flour
# 6           Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7       Kaju katli                     Cashews, ghee, cardamom, sugar
# 8         Kalakand                        Milk, cottage cheese, sugar
# 9            Kheer                    Milk, rice, sugar, dried fruits
# 10           Laddu                            Gram flour, ghee, sugar
# 11           Lassi                          Yogurt, milk, nuts, sugar
# ...

# %%
df.dropna()
# Out:
#               name                                        ingredients  \
# 0       Balu shahi                    Maida flour, yogurt, oil, sugar
# 2   Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3           Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4      Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 6           Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 9            Kheer                    Milk, rice, sugar, dried fruits
# 10           Laddu                            Gram flour, ghee, sugar
# 11           Lassi                          Yogurt, milk, nuts, sugar
# 12       Nankhatai  Refined flour, besan, ghee, powdered sugar, yo...
#
#           diet  prep_time  cook_time flavor_profile   course          state  \
# 0   vegetarian       45.0       25.0          sweet  dessert    West Bengal
# 2   vegetarian       15.0       30.0          sweet  dessert         Punjab
# ...

# %%
df.to_csv("./Result2.csv", index=True)
